# %%
import pandas as pd
path = r"C:\Users\carlo\OneDrive\Documents\Icahn\M1\MD+ Datathon\chronic_illness\data\export.csv"

df = pd.read_csv(path)
unique_values = set(df.iloc[:, 0])
len(unique_values)
